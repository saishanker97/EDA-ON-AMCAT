# %%
import numpy as np,pandas as pd,matplotlib.pyplot as plt,seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\K sai kiran\Downloads\data.xlsx - Sheet1.csv")
df
# Out:
#      Unnamed: 0      ID     Salary           DOJ           DOL  \
# 0         train  203097   420000.0   6/1/12 0:00       present
# 1         train  579905   500000.0   9/1/13 0:00       present
# 2         train  810601   325000.0   6/1/14 0:00       present
# 3         train  267447  1100000.0   7/1/11 0:00       present
# 4         train  343523   200000.0   3/1/14 0:00   3/1/15 0:00
# ...         ...     ...        ...           ...           ...
# 3993      train   47916   280000.0  10/1/11 0:00  10/1/12 0:00
# 3994      train  752781   100000.0   7/1/13 0:00   7/1/13 0:00
# 3995      train  355888   320000.0   7/1/13 0:00       present
# 3996      train  947111   200000.0   7/1/14 0:00   1/1/15 0:00
# 3997      train  324966   400000.0   2/1/13 0:00       present
#
#                       Designation           JobCity Gender           DOB  \
# 0         senior quality engineer         Bangalore      f  2/19/90 0:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3998 non-null   object
#  1   ID                     3998 non-null   int64
#  2   Salary                 3998 non-null   float64
#  3   DOJ                    3998 non-null   object
#  4   DOL                    3998 non-null   object
#  5   Designation            3998 non-null   object
#  6   JobCity                3998 non-null   object
#  7   Gender                 3998 non-null   object
#  8   DOB                    3998 non-null   object
#  9   10percentage           3998 non-null   float64
#  10  10board                3998 non-null   object
#  11  12graduation           3998 non-null   int64
#  12  12percentage           3998 non-null   float64
#  13  12board                3998 non-null   object
# ...

# %%
df['DOJ'] = pd.to_datetime(df['DOJ'])
df['DOB'] = pd.to_datetime(df['DOB'])
df.drop(columns='Unnamed: 0',inplace=True)
df
# Out:
# C:\Users\K sai kiran\AppData\Local\Temp\ipykernel_5164\2831341322.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DOJ'] = pd.to_datetime(df['DOJ'])
# C:\Users\K sai kiran\AppData\Local\Temp\ipykernel_5164\2831341322.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DOB'] = pd.to_datetime(df['DOB'])
#           ID     Salary        DOJ           DOL                  Designation  \
# 0     203097   420000.0 2012-06-01       present      senior quality engineer
# 1     579905   500000.0 2013-09-01       present            assistant manager
# 2     810601   325000.0 2014-06-01       present             systems engineer
# ...

# %%
numerical_df = df[['Salary','10percentage','12graduation','12percentage','collegeGPA','conscientiousness','agreeableness','extraversion','nueroticism','openess_to_experience']]
numerical_df
# Out:
#          Salary  10percentage  12graduation  12percentage  collegeGPA  \
# 0      420000.0         84.30          2007         95.80       78.00
# 1      500000.0         85.40          2007         85.00       70.06
# 2      325000.0         85.00          2010         68.20       70.00
# 3     1100000.0         85.60          2007         83.60       74.64
# 4      200000.0         78.00          2008         76.80       73.90
# ...         ...           ...           ...           ...         ...
# 3993   280000.0         52.09          2006         55.50       61.50
# 3994   100000.0         90.00          2009         93.00       77.30
# 3995   320000.0         81.86          2008         65.50       70.00
# 3996   200000.0         78.72          2010         69.88       70.42
# 3997   400000.0         70.60          2008         68.00       68.00
#
#       conscientiousness  agreeableness  extraversion  nueroticism  \
# ...

# %%
plt.figure(figsize=(18, 16))

# Iterate through each column and plot it
for i, col in enumerate(numerical_df):
    # Create a subplot at position i+1 in a 2x5 grid
    plt.subplot(4, 3, i+1)
    
    # Plot a boxplot of the current column using Seaborn
    sns.boxplot(x=df[col])
    
    # Set the title for the subplot
    plt.title('Box plot for ' + col)
    
    # Remove x-axis ticks and labels
    plt.xticks([])
    
    # Remove x-axis grid lines
    plt.grid(False)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
# Assuming df is your DataFrame with the original data
# Apply outlier replacement method
numerical_cols = ['Salary', '10percentage', '12graduation', '12percentage', 
                  'collegeGPA', 'conscientiousness', 'agreeableness', 
                  'extraversion', 'nueroticism', 'openess_to_experience']

for col in numerical_cols:
    median_value = df[col].median()

    def replace_outliers_with_median(val):
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        if val < lower_bound or val > upper_bound:
            return np.nan
        else:
            return val

    df[col] = df[col].apply(replace_outliers_with_median)

# Now plot box plots for the cleaned numerical columns using Seaborn
plt.figure(figsize=(18, 16))

# Iterate through each column and plot it
for i, col in enumerate(numerical_cols):
    # Create a subplot at position i+1 in a 2x5 grid
    plt.subplot(4, 3, i+1)
    
    # Plot a boxplot of the current column using Seaborn
    sns.boxplot(x=df[col])
    
    # Set the title for the subplot
    plt.title('Box plot for ' + col)
    
    # Remove x-axis ticks and labels
    plt.xticks([])
    
    # Remove x-axis grid lines
    plt.grid(False)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
df.dropna(inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3587 entries, 0 to 3997
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3587 non-null   int64
#  1   Salary                 3587 non-null   float64
#  2   DOJ                    3587 non-null   datetime64[ns]
#  3   DOL                    3587 non-null   object
#  4   Designation            3587 non-null   object
#  5   JobCity                3587 non-null   object
#  6   Gender                 3587 non-null   object
#  7   DOB                    3587 non-null   datetime64[ns]
#  8   10percentage           3587 non-null   float64
#  9   10board                3587 non-null   object
#  10  12graduation           3587 non-null   float64
#  11  12percentage           3587 non-null   float64
#  12  12board                3587 non-null   object
#  13  CollegeID              3587 non-null   int64
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Salary, DOJ, DOL, Designation, JobCity, Gender, DOB, 10percentage, 10board, 12graduation, 12percentage, 12board, CollegeID, CollegeTier, Degree, Specialization, collegeGPA, CollegeCityID, CollegeCityTier, CollegeState, GraduationYear, English, Logical, Quant, Domain, ComputerProgramming, ElectronicsAndSemicon, ComputerScience, MechanicalEngg, ElectricalEngg, TelecomEngg, CivilEngg, conscientiousness, agreeableness, extraversion, nueroticism, openess_to_experience]
# Index: []
#
# [0 rows x 38 columns]

# %%
df = df.apply(lambda x: x.str.strip().str.title() if x.dtype == "object" else x)

# %%
df.to_csv('C:\saishanker Machine Learning project\internship\EDA\cleaned_data.csv')

# %% [markdown]
# ## Univariate on Numerical

# %%
# Now plot box plots for the cleaned numerical columns using Seaborn
plt.figure(figsize=(18, 16))

# Iterate through each column and plot it
for i, col in enumerate(numerical_cols):
    # Create a subplot at position i+1 in a 2x5 grid
    plt.subplot(4, 3, i+1)
    
    # Plot a boxplot of the current column using Seaborn
    sns.boxplot(x=df[col])
    
    # Set the title for the subplot
    plt.title('Box plot for ' + col)
    
    # Remove x-axis ticks and labels
    plt.xticks([])
    
    # Remove x-axis grid lines
    plt.grid(False)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Univariate on Categorical

# %%
categorical_columns = df.select_dtypes(include='object')
# categorical_columns = categorical_columns.drop(columns='DOL',inplace=True)
categorical_columns
# Out:
#                DOL                  Designation           JobCity Gender  \
# 0          Present      Senior Quality Engineer         Bangalore      F
# 1          Present            Assistant Manager            Indore      M
# 2          Present             Systems Engineer           Chennai      F
# 4      3/1/15 0:00                          Get           Manesar      M
# 5          Present              System Engineer         Hyderabad      M
# ...            ...                          ...               ...    ...
# 3993  10/1/12 0:00            Software Engineer         New Delhi      M
# 3994   7/1/13 0:00             Technical Writer         Hyderabad      F
# 3995       Present  Associate Software Engineer         Bangalore      M
# 3996   1/1/15 0:00           Software Developer  Asifabadbanglore      F
# 3997       Present      Senior Systems Engineer           Chennai      F
#
#                              10board                             12board  \
# ...

# %%
print(df["Designation"].value_counts().head(15))
# Out:
# Designation
# Software Engineer             490
# Software Developer            238
# System Engineer               193
# Programmer Analyst            129
# Systems Engineer              110
# Java Software Engineer        101
# Software Test Engineer         87
# Technical Support Engineer     73
# Project Engineer               69
# Java Developer                 61
# Senior Software Engineer       53
# Test Engineer                  52
# Application Developer          48
# Network Engineer               48
# Web Developer                  48
# Name: count, dtype: int64

# %%
top_ten_designations = df['Designation'].value_counts().head(15)

# Create count plot using Seaborn
plt.figure(figsize=(20, 12))
ax = sns.countplot(x='Designation', data=df, order=top_ten_designations.index, palette='pastel')

# Set labels and title
ax.set_xlabel('Designation', fontsize=20)
ax.set_ylabel('Count', fontsize=20)
ax.set_title('Count Plot for Designation', fontsize=20)
plt.xticks(rotation=90)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)


# Calculate percentages and add annotations
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center', fontsize=20)

# Show the plot
# plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
top_ten_designations = df['Designation'].value_counts().head(10)

# Create count plot using Seaborn
plt.figure(figsize=(20, 15))
ax = sns.countplot(x='Designation', data=df, order=top_ten_designations.index, palette='pastel')

# Set labels and title
ax.set_xlabel('Designation', fontsize=20)
ax.set_ylabel('Count', fontsize=20)
ax.set_title('Count Plot for Designation', fontsize=20)
plt.xticks(rotation=90)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)


# Calculate percentages and add annotations
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center', fontsize=20)

# Show the plot
# plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Most of the students are employed as software engineer with 13.5% of total students followed by system engineer and software developer so on
# - The top 10 Designation account for 45% of the data.
# - Rest of the data point is less then 1%

# %% [markdown]
# ## which city has more employees?

# %%
unique_JobCity = df["JobCity"].unique()
unique_JobCity.sort()
unique_JobCity
# Out:
# array(['-1', 'Agra', 'Ahmedabad', 'Ahmednagar', 'Al Jubail,Saudi Arabia',
#        'Allahabad', 'Alwar', 'Ambala', 'Ambala City', 'Ariyalur',
#        'Asansol', 'Asifabadbanglore', 'Aurangabad', 'Baddi Hp',
#        'Bahadurgarh', 'Banagalore', 'Banaglore', 'Bangalore', 'Banglore',
#        'Bankura', 'Bareli', 'Baripada', 'Bathinda', 'Beawar', 'Belgaum',
#        'Bellary', 'Bengaluru', 'Bhagalpur', 'Bharuch', 'Bhilai', 'Bhopal',
#        'Bhubaneshwar', 'Bhubaneswar', 'Bhubneshwar', 'Bihar', 'Bikaner',
#        'Bilaspur', 'Bulandshahar', 'Bundi', 'Burdwan', 'Calicut',
#        'Chandigarh', 'Chandrapur', 'Chennai', 'Chennai & Mumbai',
#        'Chennai, Bangalore', 'Cheyyar', 'Coimbatore', 'Daman And Diu',
#        'Dausa', 'Dehradun', 'Delhi', 'Delhi/Ncr', 'Dhanbad',
#        'Dharamshala', 'Dharmapuri', 'Dharuhera', 'Ernakulam', 'Faridabad',
#        'Gagret', 'Gandhi Nagar', 'Gandhinagar', 'Ganjam', 'Gaziabaad',
# ...

# %%
len(unique_JobCity)
# Out:
# 205

# %%
df['JobCity'].replace(
    {'Ambala' : 'Ambala City', 'CHENNAI': ' Chennai', 'Bengaluru' : 'Banagalore',
     'Bengaluru' : 'Banaglore', 'Bengaluru' : 'Bangalore', 'Bengaluru' : 'Banglore',
     'Bhubaneswar' : 'Bhubneshwar', 'Bhubaneswar' : 'Bhubaneswar', 'Bhubaneswar' : 'Bhubneshwar',
     'Ghaziabad' : 'Gaziabaad', 'Hyderabad' : 'Hderabad', 'Hyderabad' : 'Secunderabad', 
     'Hyderabad' : 'Hyderabad(Bhadurpally)', 
     'Kochi' : 'Kochi/Cochin', 'Nashik' : 'Nasikcity', 'Mumbai' : 'Navi Mumbai', 'Pune' : 'Punr',
     'Orissa' : 'Odisha', 'Sonipat' : 'Sonepat', 'Tirupati' : 'Tirupathi', 'Visakhapatnam' : 'Vizag', 
     'Visakhapatnam' : 'Vsakhapttnam'},
    inplace=True)

# %%
df['JobCity'].nunique()
# Out:
# 193

# %%
df['JobCity'] = df['JobCity'].replace('-1','Not Mentioned')
top_ten_JobCity = df['JobCity'].value_counts().head(15)
top_ten_JobCity
# Out:
# JobCity
# Bangalore                 588
# Not Mentioned             425
# Noida                     356
# Hyderabad(Bhadurpally)    336
# Punr                      292
# Chennai                   290
# Gurgaon                   193
# New Delhi                 181
# Navi Mumbai               138
# Kolkata                   107
# Jaipur                     45
# Mysore                     37
# Lucknow                    36
# Bhubneshwar                29
# Chandigarh                 26
# Name: count, dtype: int64

# %%
top_ten_JobCity = df['JobCity'].value_counts().head(15)

# Create count plot using Seaborn
plt.figure(figsize=(20, 12))
ax = sns.countplot(x='JobCity', data=df,order=top_ten_JobCity.index, palette='pastel')

# Set labels and title
ax.set_xlabel('JobCity', fontsize=20)
ax.set_ylabel('Count', fontsize=20)
ax.set_title('Count Plot for JobCity', fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
plt.xticks(rotation=90)

# Calculate percentages and add annotations
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center', fontsize=20)

# Show the plot
plt.tight_layout()
plt.show()

# %%
top_ten_JobCity = df['JobCity'].value_counts().head(10)

# Create count plot using Seaborn
plt.figure(figsize=(20, 12))
ax = sns.countplot(x='JobCity', data=df,order=top_ten_JobCity.index, palette='pastel')

# Set labels and title
ax.set_xlabel('JobCity', fontsize=20)
ax.set_ylabel('Count', fontsize=20)
ax.set_title('Count Plot for JobCity', fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
plt.xticks(rotation=90)

# Calculate percentages and add annotations
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center', fontsize=20)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# - This plot only shows top ten Job Cities.
# - Most of the students got job in Bangalore followed by Noida and Hyderabad.
# - Almost 11.9% students who are employed are Not Mentioned their Job City
# - The top 10 cities account for 70% of the data.

# %% [markdown]
# ## which gender are more employed?

# %%
# top_ten_JobCity = df['Gender'].value_counts().head(10)

# Create count plot using Seaborn
plt.figure(figsize=(20, 12))
ax = sns.countplot(x='Gender', data=df,palette='pastel')

# Set labels and title
ax.set_xlabel('Gender',fontsize=20)
ax.set_ylabel('Count',fontsize=20)
ax.set_title('Count Plot for Gender',fontsize=20)
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=15)

# Calculate percentages and add annotations
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center', fontsize=20)

# Show the plot
# plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Male candidates are more who are employed i.e 76.1% compared with female candidates 23.9%
# - This Data is also an Imbalanced data w.r.t gender

# %% [markdown]
# ## which 10th board are more employed?

# %%
df['10board'] = df['10board'].replace('0','Not Mentioned')

# %%
# Get top ten 10boards
top_ten_10boards = df['10board'].value_counts().head(10)

# Create count plot using Seaborn
plt.figure(figsize=(20, 12))
ax = sns.countplot(x='10board', data=df, order=top_ten_10boards.index, palette='pastel')

# Set labels and title with increased font size
ax.set_xlabel('10board', fontsize=20)
ax.set_ylabel('Count', fontsize=20)
ax.set_title('Count Plot for 10board', fontsize=24)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
plt.xticks(rotation=90, fontsize=20)  # Rotate x-axis labels and set their font size

# Calculate percentages and add annotations with increased font size
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, 
            '{:.1f}%'.format((height / total) * 100),
            ha='center', fontsize=20)  # Corrected 'ha' parameter and increased font size for percentages

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# - This plot only shows top ten 10th boards among all.
# - Most of the employed candidates their 10th board is cbse with atmost of 34.9% of students followed by stateboard and icse.
# - 8.8% of students not mentioned there 10th board.

# %% [markdown]
# ## which 12th board are more employed?

# %%
df['12board'] = df['12board'].replace('board of intermediate','board of intermediate education')
df['12board'] = df['12board'].replace('0','Not Mentioned')

# %%
top_ten_12boards = df['12board'].value_counts().head(10)

# Create count plot using Seaborn
plt.figure(figsize=(20, 15))
ax = sns.countplot(x='12board', data=df,order=top_ten_12boards.index,palette='pastel')

# Set labels and title
ax.set_xlabel('12board', fontsize=20)
ax.set_ylabel('Count', fontsize=20)
ax.set_title('Count Plot for 12board', fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
plt.xticks(rotation=90, fontsize=20)

# Calculate percentages and add annotations
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center', fontsize=20)

# Show the plot
# plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# - This plot only shows top ten 12th boards among all.
# - Most of the employed candidates their 12th board is cbse with atmost of 35% of students followed by stateboard and icse.
# - 9% of students not mentioned there 12th board.

# %% [markdown]
# ## Employees with which Degree are more employed?

# %%
plt.figure(figsize=(20, 12))
ax = sns.countplot(x='Degree', data=df,palette='pastel')

# Set labels and title
ax.set_xlabel('Degree', fontsize=20)
ax.set_ylabel('Count', fontsize=20)
ax.set_title('Count Plot for Degree', fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)


# Calculate percentages and add annotations
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center', fontsize=20)

# Show the plot
# plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Most of the students have their Degree is Btech with almost of 92.5% followed by MCA, M.Tech/M.E and M.Sc

# %% [markdown]
# ## Which Specialization are more employed?

# %%
top_ten_Specialization = df['Specialization'].value_counts().head(10)

# Create count plot using Seaborn
plt.figure(figsize=(30, 20))
ax = sns.countplot(x='Specialization', data=df,order=top_ten_Specialization.index,palette='pastel')

# Set labels and title
ax.set_xlabel('Specialization', fontsize=30)
ax.set_ylabel('Count', fontsize=30)
ax.set_title('Count Plot for Specialization', fontsize=30)
ax.tick_params(axis='x', labelsize=30)
ax.tick_params(axis='y', labelsize=30)
plt.xticks(rotation=90, fontsize=30)

# Calculate percentages and add annotations
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center', fontsize=30)

# Show the plot
# plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# - This plot contains only top 10 Specializations among many of them
# - Most of the students with Degree Specialization is electronics  and communication engineering with 22% followed by computer science and engineering with 18.6%, Information Technology with 16.5%

# %% [markdown]
# ## Which State are more employed?

# %%
top_ten_Specialization = df['CollegeState'].value_counts().tail(10)

# Create count plot using Seaborn
plt.figure(figsize=(20, 10))
ax = sns.countplot(x='CollegeState', data=df,order=top_ten_Specialization.index,palette='pastel')

# Set labels and title
ax.set_xlabel('CollegeState', fontsize=20)
ax.set_ylabel('Count', fontsize=20)
ax.set_title('Count Plot for CollegeState', fontsize=20)
ax.tick_params(axis='y', labelsize=20)
ax.tick_params(axis='x', labelsize=20)
plt.xticks(rotation=90, fontsize=20)

# Calculate percentages and add annotations
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center', fontsize=20)

# Show the plot
# plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
top_ten_Specialization = df['CollegeState'].value_counts().head(10)

# Create count plot using Seaborn
plt.figure(figsize=(20, 10))
ax = sns.countplot(x='CollegeState', data=df,order=top_ten_Specialization.index,palette='pastel')

# Set labels and title
ax.set_xlabel('CollegeState', fontsize=20)
ax.set_ylabel('Count', fontsize=20)
ax.set_title('Count Plot for CollegeState', fontsize=20)
ax.tick_params(axis='y', labelsize=20)
ax.tick_params(axis='x', labelsize=20)
plt.xticks(rotation=90, fontsize=20)

# Calculate percentages and add annotations
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, '{:.1f}%'.format((height / total) * 100), ha='center', fontsize=20)

# Show the plot
# plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# - This plot contains only top 10 CollegeState among many of them
# - Most of the students are from Uttar Pradesh with 22.9% followed by karnataka with 9.3% followed by Tamilnadu 9.2% so on
